# %% [markdown]
# # Brain Tumor Notebook Test
# This notebook is included to verify `.ipynb` ingestion and chunking.

# %% [markdown]
# ## Model Summary
# This project uses a MobileNetV2 based CNN model to classify brain MRI images.

# %% [markdown]
# ## Dataset Information
# MRI scans are categorized into **Glioma**, **Meningioma**, **Pituitary** and **No Tumor**.

# %%
# Step 1: Verification Code
print("Notebook successfully loaded into RAG index!")

# %%
# Example preprocessing step
import numpy as np
img = np.zeros((150, 150, 3))
print("Dummy MRI image created", img.shape)
